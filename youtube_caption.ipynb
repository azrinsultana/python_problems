# %% [markdown]
# <a href="https://colab.research.google.com/github/azrinsultana/python_problems/blob/main/youtube_caption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U youtube-transcript-api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

def get_youtube_captions(video_id):
    try:
        api = YouTubeTranscriptApi()
        transcript_list = api.list(video_id)

        transcript = transcript_list.find_transcript(['en']).fetch()

        full_text = " ".join([segment.text for segment in transcript])
        return full_text

    except Exception as e:
        return f"Error: {e}"

video_id = "b3NmhxUDt-4"
print(get_youtube_captions(video_id))
# Out:
# The psychology of it is very complicated. People switch off, and I think you have to pick your moments of discussing climate change where it really, really does matter. Try making a weekly programme about climate change, Matt! Today we're going to answer one of the most searched climate questions. What's the difference between weather and the climate? From the BBC World Service, I'm Jordan Dunbar and a few weeks ago, Graihagh Jackson and I got to find out. Our guest today is Matt Taylor, lead weather forecaster at the BBC, and I'd say one of the UK's most recognisable forecasters. Welcome Matt, thanks so much. Thank you very much for having me.
# ...
