# %%
from types import resolve_bases
class Arr:
  def __init__(self, arr):
    self.arr = arr
  def alternateArr(self):
    res = []
    for i in range(0,len(self.arr),2):
      res.append(self.arr[i])
    return res
  def getArr(self):
    result = self.alternateArr()
    print(result)

arr1 = Arr([12,13,4,567,234,6])
arr1.getArr()
# Out:
# [12, 4, 234]
